# %% [markdown]
# Basic Statistics

# %%
'''
Question 1: What is the difference between descriptive statistics and inferential statistics? Explain with examples.
Answer: 
       • Descriptive Statistics: Summarize and describe the main features of a dataset.
         Example: Calculating the mean test score of a class of 40 students.
       • Inferential Statistics: Use sample data to make predictions or inferences about a larger population.
         Example: Taking a sample of 100 voters to predict the outcome of an election.

Question 2: What is sampling in statistics? Explain the differences between random and stratified sampling. 
Answer:
       • Sampling: Process of selecting a subset of data from a larger population for analysis.
       • Random Sampling: Every individual has an equal chance of selection (e.g., lottery).
       • Stratified Sampling: Population divided into groups (strata), and samples are taken from each group proportionally (e.g., sampling students by year in college).

Question 3: Define mean, median, and mode. Explain why these measures of central tendency are important. 
Answer:
       • Mean: Arithmetic average of values.
       • Median: Middle value when data is ordered.
       • Mode: Most frequently occurring value.
       • Importance: These measures represent the central tendency of data, helping summarize datasets with a single representative value.

Question 4: Explain skewness and kurtosis. What does a positive skew imply about the data?
Answer:
       • Skewness: Measure of asymmetry of data distribution.
       • Kurtosis: Measure of "tailedness" of data distribution.
       • Positive Skew: Data has a long right tail, meaning most values are low, but some high outliers pull the mean to the right. 
         Example: income distribution.
'''

# %%
#Question 5: Implement a Python program to compute the mean, median, and mode of a given list of numbers. 
#numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]
#Answer:

import statistics as stats
numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]
mean = stats.mean(numbers)
median = stats.median(numbers)
mode = stats.mode(numbers)
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 19.6
# Median: 19
# Mode: 12

# %%
#Question 6: Compute the covariance and correlation coefficient between the following two datasets provided as lists in Python: 
#list_x = [10, 20, 30, 40, 50] 
#list_y = [15, 25, 35, 45, 60]
#Answer:

import numpy as np
list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]
cov_matrix = np.cov(list_x, list_y, bias=True)
covariance = cov_matrix[0][1]
correlation = np.corrcoef(list_x, list_y)[0][1]
print("Covariance:", covariance)
print("Correlation Coefficient:", correlation)
# Out:
# Covariance: 220.0
# Correlation Coefficient: 0.995893206467704

# %%
#Question 7: Write a Python script to draw a boxplot for the following numeric list and identify its outliers. Explain the result: 
#data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
#Answer:

import matplotlib.pyplot as plt
data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
plt.boxplot(data)
plt.title("Boxplot of Data")
plt.show()
#Explanation: The boxplot shows most values clustered between 18–26. Value 35 appears as an outlier (far above the upper whisker).

# %%
#Question 8: You are working as a data analyst in an e-commerce company. The marketing team wants to know if there is a relationship between advertising spend and daily sales. 
#● Explain how you would use covariance and correlation to explore this relationship.
#● Write Python code to compute the correlation between the two lists: 
#advertising_spend = [200, 250, 300, 400, 500] 
#daily_sales = [2200, 2450, 2750, 3200, 4000]
#Answer: 

advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]
correlation = np.corrcoef(advertising_spend, daily_sales)[0][1]
print("Correlation:", correlation)
# Out:
# Correlation: 0.9935824101653329

# %%
#Question 9: Your team has collected customer satisfaction survey data on a scale of 1-10 and wants to understand its distribution before launching a new product. 
#● Explain which summary statistics and visualizations (e.g. mean, standard deviation, histogram) you’d use. 
#● Write Python code to create a histogram using Matplotlib for the survey data: 
#survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]
#Answer:
#•	Summary statistics: Mean, median, standard deviation.
#•	Visualization: Histogram to check distribution; boxplot for outliers.

survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]
mean = stats.mean(survey_scores)
stdev = stats.stdev(survey_scores)
print("Mean:", mean)
print("Standard Deviation:", stdev)
plt.hist(survey_scores, bins=6, edgecolor="black")
plt.title("Customer Satisfaction Survey Distribution")
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 7.333333333333333
# Standard Deviation: 1.632993161855452
